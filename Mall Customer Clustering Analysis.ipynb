# %%
# Importing required Libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('fivethirtyeight')
import dabl

# %%
# Reading and Loading the data set
data = pd.read_csv('Mall_Customers.csv')
data.head()
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
# Checking the size of the dataset

print('The shape of the dataset :', data.shape)
# Out:
# The shape of the dataset : (200, 5)

# %%
# Let's check the pairplot of the data

sns.pairplot(data)
plt.show()

# %%
# Lets analyse the data in correlation to spending score

plt.rcParams['figure.figsize'] = (18, 6)
plt.style.use('fivethirtyeight')
dabl.plot(data, target_col = 'Spending Score (1-100)')
# Out:
# Target looks like regression
# C:\Users\HP\anaconda3\lib\site-packages\dabl\plot\utils.py:374: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(
# [array([[<AxesSubplot:title={'center':'F=2.37E+01'}, xlabel='Age', ylabel='Spending Score (1...'>,
#          <AxesSubplot:title={'center':'F=1.94E-02'}, xlabel='Annual Income (k$)'>]],
#        dtype=object),
#  array([[<AxesSubplot:title={'center':'F=6.73E-02'}, xlabel='Spending Score (1...', ylabel='Gender'>]],
#        dtype=object)]

# %% [markdown]
# ## Descriptive Statistics

# %%
# Desciping the data

data.describe()
# Out:
#        CustomerID         Age  Annual Income (k$)  Spending Score (1-100)
# count  200.000000  200.000000          200.000000              200.000000
# mean   100.500000   38.850000           60.560000               50.200000
# std     57.879185   13.969007           26.264721               25.823522
# min      1.000000   18.000000           15.000000                1.000000
# 25%     50.750000   28.750000           41.500000               34.750000
# 50%    100.500000   36.000000           61.500000               50.000000
# 75%    150.250000   49.000000           78.000000               73.000000
# max    200.000000   70.000000          137.000000               99.000000

# %%
# Describing the categorical data
data.describe(include = 'object')
# Out:
#         Gender
# count      200
# unique       2
# top     Female
# freq       112

# %%
#Check if theres any null data
data.isna().any().any()
# Out:
# False

# %% [markdown]
# ## Data Visualisation

# %%
import warnings
warnings.filterwarnings('ignore')

plt.rcParams['figure.figsize'] = (18, 8)

plt.subplot(1, 2, 1)
sns.set(style = 'whitegrid')
sns.distplot(data['Annual Income (k$)'])
plt.title('Distribution of Annual Income', fontsize = 20)
plt.xlabel('Range of Annual Income')
plt.ylabel('Count')


plt.subplot(1, 2, 2)
sns.set(style = 'whitegrid')
sns.distplot(data['Age'], color = 'red')
plt.title('Distribution of Age', fontsize = 20)
plt.xlabel('Range of Age')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# > Here, In the above Plots we can see the Distribution pattern of Annual Income and Age, By looking at the plots,
#
# >> we can infer one thing that There are few people who earn more than 100 US Dollars.
# >> Most of the people have an earning of around 50-75 US Dollars.
# >> Also, we can say that the least Income is around 20 US Dollars.
#
# > Taking inferences about the Customers.
# >> The most regular customers for the Mall has age around 30-35 years of age.
# >> Whereas the the senior citizens age group is the least frequent visitor in the Mall.
# >> Youngsters are lesser in number as compared to the Middle aged people.

# %%
labels = ['Female', 'Male']
size = data['Gender'].value_counts()
colors = ['lightgreen', 'orange']
explode = [0, 0.001]

plt.rcParams['figure.figsize'] = (9, 9)
plt.pie(size, colors = colors, explode = explode, labels = labels, shadow = True, startangle = 90, autopct = '%.2f%%')
plt.title('Gender Gap', fontsize = 20)
plt.axis('off')
plt.legend()
plt.show()

# %% [markdown]
# > By looking at the piecart above showing the Distribution of Gender in the Mall
# >> Whereabout Females are about 56% whereas males are 44%, thats a huge gap when comparatively population of Males ought to be higher than Females

# %%
plt.rcParams['figure.figsize'] = (15, 8)
sns.countplot(data['Age'], palette = 'hsv')
plt.title('Distribution of Age', fontsize = 20)
plt.show()

# %% [markdown]
# > This Graph shows a more Interactive Chart about the distribution of each Age Group in the Mall for more clariy about the Visitor's Age Group in the Mall.
# >> By looking at the above graph-, It can be seen that the Ages from 27 to 39 are very much frequent but there is no clear pattern, we can only find some group wise patterns such as the the older age groups are lesser frequent in comparison.
# >> Interesting Fact, There are equal no. of Visitors in the Mall for the Agee 18 and 67.
# >> People of Age 55, 56, 69, 64 are very less frequent in the Malls.
# >> People at Age 32 are the Most Frequent Visitors in the Mall.

# %%
# lets check the sitribution of Annual Income

plt.rcParams['figure.figsize'] = (20, 8)
sns.distplot(data['Annual Income (k$)'], color = 'red')
plt.title('Distribution of Annual Income', fontsize = 20)
plt.show()

# %% [markdown]
# > Again, This is also a chart to better explain the Distribution of Each Income level, Interesting there are customers in the mall with a very much comparable freqyuency with their Annual Income ranging from 15 US Dollars to 137K US Dollars.
# >> There are more Customers in the Mall whoc have their Annual Income as 54k US Dollars or 78 US Dollars.

# %%
# lets check the distribution of Spending Score

plt.rcParams['figure.figsize'] = (20, 8)
sns.distplot(data['Spending Score (1-100)'], color = 'black')
plt.title('Distribution of Spending Score', fontsize = 20)
plt.show()

# %% [markdown]
# > This is the Most Important Chart in the perspective of Mall, as It is very Important to have some intuition and idea about the Spending Score of the Customers Visiting the Mall.
# >> On a general level, we may conclude that most of the Customers have their Spending Score in the range of 35-60.
# >> Interesting there are customers having I spending score also, and 99 Spending score also, Which shows that the mall caters to the variety of Customers with Varying needs and requirements available in the Mall.

# %% [markdown]
# > The Above Graph for Showing the correlation between the different attributes of the Mall Customer Segementation Dataset, This Heat map reflects the most correlated features with Orange Color and least correlated features with yellow color.
# >> We can clearly see that these attributes do not have good correlation among them, that's why we will proceed with all of the features.

# %%
#  Gender vs Spendscore

plt.rcParams['figure.figsize'] = (18, 7)
sns.boxenplot(data['Gender'], data['Spending Score (1-100)'], palette = 'Blues')
plt.title('Gender vs Spending Score', fontsize = 20)
plt.show()

# %% [markdown]
# > Bi-variate Analysis between Gender and Spending Score,
# >> It is clearly visible that the most of the males have a Spending Score of around 25k US Dollars to 70k US Dollars whereas the Females have a spending score of around 35k US Dollars to 75k US Dollars. which again points to the fact that women are Shopping Leaders.

# %%
## Gender vs Annual Income

plt.rcParams['figure.figsize'] = (18, 7)
sns.violinplot(data['Gender'], data['Annual Income (k$)'], palette = 'rainbow')
plt.title('Gender vs Annual Income', fontsize = 20)
plt.show()

# %% [markdown]
# > Again a Bivariate Analysis between the Gender and the Annual Income, to better visualize the Income of the different Genders.
# >> There are more number of males who get paid more than females. But, The number of males and females are equal in number when it comes to low annual income.

# %%
# Gender vs Age

plt.rcParams['figure.figsize'] = (18, 7)
sns.stripplot(data['Gender'], data['Age'], palette = 'Purples', size = 10)
plt.title('Gender vs Age', fontsize = 20)
plt.show()

# %%
# Annual Income vs Age and Spending Score

x = data['Annual Income (k$)']
y = data['Age']
z = data['Spending Score (1-100)']

sns.lineplot(x, y, color = 'blue')
sns.lineplot(x, z, color = 'pink')
plt.title('Annual Income vs Age and Spending Score', fontsize = 20)
plt.show()

# %% [markdown]
# > The above Plot Between Annual Income and Age represented by a blue color line, and a plot between Annual Income and the Spending Score represented by a pink color. shows how Age and Spending Varies with Annual Income.

# %% [markdown]
# ## Clustering Analysis

# %%
# Let's select the spending score and annual income from the data
x = data.loc[:, ['Spending Score (1-100)', 'Annual Income (k$)']].values

# Lets check the shape of x
x.shape
# Out:
# (200, 2)

# %%
# lets also check the data, which we are going to use for the clustering analysis
x_data  = pd.DataFrame(x)
x_data.head()
# where o->Spending Score, and 1->Annual Income
# Out:
#     0   1
# 0  39  15
# 1  81  15
# 2   6  16
# 3  77  16
# 4  40  17

# %% [markdown]
# ## KMeans Algorithm

# %%
from sklearn.cluster import KMeans

wcss = []
for i in range(1, 11):
    km = KMeans(n_clusters = i, init = 'k-means++', max_iter = 300, n_init = 10, random_state = 0)
    km.fit(x)
    wcss.append(km.inertia_)
    
plt.plot(range(1, 11), wcss)
plt.title('The Elbow Method', fontsize = 20)
plt.xlabel('No. of Clusters')
plt.ylabel('wcss')
plt.show()

# %%
# lets visualize these clusters

plt.style.use('fivethirtyeight')

km = KMeans(n_clusters = 5, init = 'k-means++', max_iter = 300, n_init = 10, random_state = 0)
y_means = km.fit_predict(x)

plt.scatter(x[y_means == 0, 0], x[y_means == 0, 1], s = 100, c = 'pink', label = 'miser')
plt.scatter(x[y_means == 1, 0], x[y_means == 1, 1], s = 100, c = 'yellow', label = 'general')
plt.scatter(x[y_means == 2, 0], x[y_means == 2, 1], s = 100, c = 'cyan', label = 'target')
plt.scatter(x[y_means == 3, 0], x[y_means == 3, 1], s = 100, c = 'magenta', label = 'spendthrift')
plt.scatter(x[y_means == 4, 0], x[y_means == 4, 1], s = 100, c = 'orange', label = 'careful')
plt.scatter(km.cluster_centers_[:,0], km.cluster_centers_[:, 1], s = 50, c = 'blue' , label = 'centeroid')

plt.style.use('fivethirtyeight')
plt.title('K Means Clustering between Annual Income and Spending Score', fontsize = 20)
plt.xlabel('Annual Income')
plt.ylabel('Spending Score')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# > This Clustering Analysis gives us a very clear insight about the different segments of the customers in the Mall. There are clearly Five segments of Customers namely Miser, General, Target, Spendthrift,  Careful based on their Annual Income and Spending Score which are reportedly the best factors/attributes to determine the segments of a customer in a Mall.

# %%
# Clustering between Age and Spending Score

from sklearn.cluster import KMeans

wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters = i, init = 'k-means++', max_iter = 300, n_init = 10, random_state = 0)
    kmeans.fit(x)
    wcss.append(kmeans.inertia_)

plt.rcParams['figure.figsize'] = (15, 5)
plt.plot(range(1, 11), wcss)
plt.title('K-Means Clustering(The Elbow Method)', fontsize = 20)
plt.xlabel('Age')
plt.ylabel('Count')
plt.grid()
plt.show()

# %%
kmeans = KMeans(n_clusters = 4, init = 'k-means++', max_iter = 300, n_init = 10, random_state = 0)
ymeans = kmeans.fit_predict(x)

plt.rcParams['figure.figsize'] = (10, 10)
plt.title('Cluster of Ages', fontsize = 30)

plt.scatter(x[ymeans == 0, 0], x[ymeans == 0, 1], s = 100, c = 'pink', label = 'Usual Customers' )
plt.scatter(x[ymeans == 1, 0], x[ymeans == 1, 1], s = 100, c = 'orange', label = 'Priority Customers')
plt.scatter(x[ymeans == 2, 0], x[ymeans == 2, 1], s = 100, c = 'lightgreen', label = 'Target Customers(Young)')
plt.scatter(x[ymeans == 3, 0], x[ymeans == 3, 1], s = 100, c = 'red', label = 'Target Customers(Old)')
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s = 50, c = 'black')

plt.style.use('fivethirtyeight')
plt.xlabel('Age')
plt.ylabel('Spending Score (1-100)')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# >According to my own intuition by looking at the above clustering plot between the age of the customers and their corresponding spending scores, I have aggregated them into 4 different categories namely Usual Customers, Priority Customers, Senior Citizen Target Customers, Young Target Customers. Then after getting the results we can accordingly make different marketing strategies and policies to  optimize the spending scores of the customer in the Mall.

# %%
#Descrete Age into different Category

print("Minimum Age :", data['Age'].min())
print("Maximum Age :", data['Age'].max())
# Out:
# Minimum Age : 18
# Maximum Age : 70

# %%
# Understanding the impact of Spending Score on different Age group

# lets use the groupby function to understand that
data[['Age', 'Spending Score (1-100)']].groupby(['Age']).agg(['min','mean','max']).style.background_gradient(cmap = 'copper')
# Out:
# <style type="text/css">
# #T_f6411_row0_col0, #T_f6411_row8_col2, #T_f6411_row48_col2 {
#   background-color: #aa6c45;
#   color: #f1f1f1;
# }
# #T_f6411_row0_col1 {
#   background-color: #dc8b59;
#   color: #f1f1f1;
# }
# #T_f6411_row0_col2, #T_f6411_row6_col2, #T_f6411_row18_col2 {
#   background-color: #ffb976;
#   color: #000000;
# }
# #T_f6411_row1_col0, #T_f6411_row2_col0, #T_f6411_row28_col0, #T_f6411_row39_col0 {
#   background-color: #100a06;
#   color: #f1f1f1;
# }
# #T_f6411_row1_col1 {
#   background-color: #8e5a39;
#   color: #f1f1f1;
# }
# #T_f6411_row1_col2, #T_f6411_row31_col2, #T_f6411_row36_col2, #T_f6411_row47_col2 {
#   background-color: #b8744a;
#   color: #f1f1f1;
# }
# #T_f6411_row2_col1 {
#   background-color: #8f5b3a;
#   color: #f1f1f1;
# }
# #T_f6411_row2_col2 {
#   background-color: #ed9660;
#   color: #f1f1f1;
# }
# #T_f6411_row3_col0, #T_f6411_row11_col0, #T_f6411_row42_col2, #T_f6411_row50_col2 {
#   background-color: #ae6e46;
#   color: #f1f1f1;
# }
# #T_f6411_row3_col1 {
#   background-color: #f69b63;
#   color: #000000;
# }
# #T_f6411_row3_col2 {
#   background-color: #ffa267;
#   color: #000000;
# }
# #T_f6411_row4_col0, #T_f6411_row7_col2, #T_f6411_row50_col0 {
#   background-color: #e6915d;
#   color: #f1f1f1;
# }
# #T_f6411_row4_col1, #T_f6411_row10_col1 {
#   background-color: #ffa468;
#   color: #000000;
# }
# #T_f6411_row4_col2 {
#   background-color: #fa9e64;
#   color: #000000;
# }
# #T_f6411_row5_col0, #T_f6411_row23_col2 {
#   background-color: #774b30;
#   color: #f1f1f1;
# }
# #T_f6411_row5_col1 {
#   background-color: #e9945e;
#   color: #f1f1f1;
# }
# #T_f6411_row5_col2, #T_f6411_row12_col1 {
#   background-color: #ffbd78;
#   color: #000000;
# }
# #T_f6411_row6_col0 {
#   background-color: #d98958;
#   color: #f1f1f1;
# }
# #T_f6411_row6_col1 {
#   background-color: #ffa76a;
#   color: #000000;
# }
# #T_f6411_row7_col0, #T_f6411_row19_col1 {
#   background-color: #2f1e13;
#   color: #f1f1f1;
# }
# #T_f6411_row7_col1, #T_f6411_row35_col2, #T_f6411_row49_col2 {
#   background-color: #8d5939;
#   color: #f1f1f1;
# }
# #T_f6411_row8_col0 {
#   background-color: #e28f5b;
#   color: #f1f1f1;
# }
# #T_f6411_row8_col1 {
#   background-color: #c77e50;
#   color: #f1f1f1;
# }
# #T_f6411_row9_col0 {
#   background-color: #c47c4f;
#   color: #f1f1f1;
# }
# #T_f6411_row9_col1 {
#   background-color: #dd8c59;
#   color: #f1f1f1;
# }
# #T_f6411_row9_col2 {
#   background-color: #ffb372;
#   color: #000000;
# }
# #T_f6411_row10_col0, #T_f6411_row13_col0, #T_f6411_row20_col0, #T_f6411_row32_col1, #T_f6411_row49_col1 {
#   background-color: #a66943;
#   color: #f1f1f1;
# }
# #T_f6411_row10_col2, #T_f6411_row12_col2 {
#   background-color: #ffc37c;
#   color: #000000;
# }
# #T_f6411_row11_col1 {
#   background-color: #ffb472;
#   color: #000000;
# }
# #T_f6411_row11_col2 {
#   background-color: #ffb170;
#   color: #000000;
# }
# #T_f6411_row12_col0, #T_f6411_row15_col2, #T_f6411_row22_col2 {
#   background-color: #ffbf7a;
#   color: #000000;
# }
# #T_f6411_row13_col1, #T_f6411_row17_col1 {
#   background-color: #eb945f;
#   color: #f1f1f1;
# }
# #T_f6411_row13_col2, #T_f6411_row14_col2 {
#   background-color: #ffbb77;
#   color: #000000;
# }
# #T_f6411_row14_col0 {
#   background-color: #482d1d;
#   color: #f1f1f1;
# }
# #T_f6411_row14_col1, #T_f6411_row37_col0 {
#   background-color: #f39a62;
#   color: #000000;
# }
# #T_f6411_row15_col0 {
#   background-color: #1e130c;
#   color: #f1f1f1;
# }
# #T_f6411_row15_col1 {
#   background-color: #c67d50;
#   color: #f1f1f1;
# }
# #T_f6411_row16_col0, #T_f6411_row19_col0, #T_f6411_row44_col1, #T_f6411_row44_col2 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_f6411_row16_col1 {
#   background-color: #8c5838;
#   color: #f1f1f1;
# }
# #T_f6411_row16_col2 {
#   background-color: #ffb573;
#   color: #000000;
# }
# #T_f6411_row17_col0 {
#   background-color: #150d08;
#   color: #f1f1f1;
# }
# #T_f6411_row17_col2, #T_f6411_row21_col0, #T_f6411_row21_col1 {
#   background-color: #ffc77f;
#   color: #000000;
# }
# #T_f6411_row18_col0 {
#   background-color: #26180f;
#   color: #f1f1f1;
# }
# #T_f6411_row18_col1, #T_f6411_row49_col0 {
#   background-color: #bf794d;
#   color: #f1f1f1;
# }
# #T_f6411_row19_col2 {
#   background-color: #5f3c26;
#   color: #f1f1f1;
# }
# #T_f6411_row20_col1 {
#   background-color: #e8935e;
#   color: #f1f1f1;
# }
# #T_f6411_row20_col2, #T_f6411_row21_col2 {
#   background-color: #ffb774;
#   color: #000000;
# }
# #T_f6411_row22_col0, #T_f6411_row34_col0 {
#   background-color: #332014;
#   color: #f1f1f1;
# }
# #T_f6411_row22_col1 {
#   background-color: #ac6d45;
#   color: #f1f1f1;
# }
# #T_f6411_row23_col0, #T_f6411_row24_col0, #T_f6411_row25_col0 {
#   background-color: #442b1b;
#   color: #f1f1f1;
# }
# #T_f6411_row23_col1, #T_f6411_row39_col1 {
#   background-color: #603d27;
#   color: #f1f1f1;
# }
# #T_f6411_row24_col1, #T_f6411_row40_col0 {
#   background-color: #3b2518;
#   color: #f1f1f1;
# }
# #T_f6411_row24_col2, #T_f6411_row26_col2 {
#   background-color: #382316;
#   color: #f1f1f1;
# }
# #T_f6411_row25_col1 {
#   background-color: #784c30;
#   color: #f1f1f1;
# }
# #T_f6411_row25_col2, #T_f6411_row33_col2, #T_f6411_row46_col2 {
#   background-color: #9a623e;
#   color: #f1f1f1;
# }
# #T_f6411_row26_col0 {
#   background-color: #19100a;
#   color: #f1f1f1;
# }
# #T_f6411_row26_col1, #T_f6411_row40_col2 {
#   background-color: #281910;
#   color: #f1f1f1;
# }
# #T_f6411_row27_col0 {
#   background-color: #73492e;
#   color: #f1f1f1;
# }
# #T_f6411_row27_col1 {
#   background-color: #855436;
#   color: #f1f1f1;
# }
# #T_f6411_row27_col2 {
#   background-color: #a46842;
#   color: #f1f1f1;
# }
# #T_f6411_row28_col1 {
#   background-color: #462d1c;
#   color: #f1f1f1;
# }
# #T_f6411_row28_col2 {
#   background-color: #875536;
#   color: #f1f1f1;
# }
# #T_f6411_row29_col0 {
#   background-color: #21150d;
#   color: #f1f1f1;
# }
# #T_f6411_row29_col1 {
#   background-color: #623e27;
#   color: #f1f1f1;
# }
# #T_f6411_row29_col2, #T_f6411_row38_col0, #T_f6411_row45_col0 {
#   background-color: #915b3a;
#   color: #f1f1f1;
# }
# #T_f6411_row30_col0, #T_f6411_row30_col1 {
#   background-color: #955f3c;
#   color: #f1f1f1;
# }
# #T_f6411_row30_col2 {
#   background-color: #975f3d;
#   color: #f1f1f1;
# }
# #T_f6411_row31_col0, #T_f6411_row36_col0, #T_f6411_row47_col0 {
#   background-color: #362216;
#   color: #f1f1f1;
# }
# #T_f6411_row31_col1 {
#   background-color: #99613e;
#   color: #f1f1f1;
# }
# #T_f6411_row32_col0 {
#   background-color: #6a432b;
#   color: #f1f1f1;
# }
# #T_f6411_row32_col2, #T_f6411_row46_col1 {
#   background-color: #b27048;
#   color: #f1f1f1;
# }
# #T_f6411_row33_col0, #T_f6411_row43_col0, #T_f6411_row48_col0 {
#   background-color: #b37148;
#   color: #f1f1f1;
# }
# #T_f6411_row33_col1 {
#   background-color: #a86a44;
#   color: #f1f1f1;
# }
# #T_f6411_row34_col1 {
#   background-color: #452c1c;
#   color: #f1f1f1;
# }
# #T_f6411_row34_col2 {
#   background-color: #553622;
#   color: #f1f1f1;
# }
# #T_f6411_row35_col0, #T_f6411_row42_col0 {
#   background-color: #0c0805;
#   color: #f1f1f1;
# }
# #T_f6411_row35_col1 {
#   background-color: #543522;
#   color: #f1f1f1;
# }
# #T_f6411_row36_col1 {
#   background-color: #7e5033;
#   color: #f1f1f1;
# }
# #T_f6411_row37_col1 {
#   background-color: #d48656;
#   color: #f1f1f1;
# }
# #T_f6411_row37_col2 {
#   background-color: #b47249;
#   color: #f1f1f1;
# }
# #T_f6411_row38_col1 {
#   background-color: #7c4e32;
#   color: #f1f1f1;
# }
# #T_f6411_row38_col2 {
#   background-color: #69422a;
#   color: #f1f1f1;
# }
# #T_f6411_row39_col2, #T_f6411_row43_col2 {
#   background-color: #9e6440;
#   color: #f1f1f1;
# }
# #T_f6411_row40_col1 {
#   background-color: #2e1d12;
#   color: #f1f1f1;
# }
# #T_f6411_row41_col0 {
#   background-color: #2a1b11;
#   color: #f1f1f1;
# }
# #T_f6411_row41_col1 {
#   background-color: #74492f;
#   color: #f1f1f1;
# }
# #T_f6411_row41_col2 {
#   background-color: #bc774c;
#   color: #f1f1f1;
# }
# #T_f6411_row42_col1 {
#   background-color: #805134;
#   color: #f1f1f1;
# }
# #T_f6411_row43_col1 {
#   background-color: #a96b44;
#   color: #f1f1f1;
# }
# #T_f6411_row44_col0 {
#   background-color: #070503;
#   color: #f1f1f1;
# }
# #T_f6411_row45_col1 {
#   background-color: #9c623f;
#   color: #f1f1f1;
# }
# #T_f6411_row45_col2 {
#   background-color: #a16641;
#   color: #f1f1f1;
# }
# #T_f6411_row46_col0 {
#   background-color: #c87f51;
#   color: #f1f1f1;
# }
# #T_f6411_row47_col1 {
#   background-color: #945e3c;
#   color: #f1f1f1;
# }
# #T_f6411_row48_col1 {
#   background-color: #b17047;
#   color: #f1f1f1;
# }
# #T_f6411_row50_col1 {
#   background-color: #cb8052;
#   color: #f1f

# %%
# let's filter the Top Customers

data[['CustomerID','Annual Income (k$)','Spending Score (1-100)']][(data['Annual Income (k$)'] > 75)
        & (data['Spending Score (1-100)'] > 75)].sort_values(by = 'Spending Score (1-100)', ascending = False).head(10)
# Out:
#      CustomerID  Annual Income (k$)  Spending Score (1-100)
# 185         186                  99                      97
# 145         146                  77                      97
# 167         168                  86                      95
# 163         164                  81                      93
# 173         174                  87                      92
# 193         194                 113                      91
# 179         180                  93                      90
# 149         150                  78                      90
# 155         156                  78                      89
# 151         152                  78                      88

# %% [markdown]
# # Thank You !!!
